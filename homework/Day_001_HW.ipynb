# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    MSE = sum((y-yp)**2)/len(y)
    return MSE

def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 183.291
# The Mean absolute error is 10.823

# %% [markdown]
# # 作業 1

# %% [markdown]
# 在Kaggle上我所關注的資料集為：Breast Cancer Wisconsin (Prognostic) Data Set
#
# 1.這項資料重要的地方在於對公眾的利益，癌症能夠在早期被發現的機率不高，但若能夠及早發現，其治癒率越高，因此如果能夠使用數據分析的方法來預測可能得癌症的機率，那麼便能夠對於人類以及醫療方面有很大的幫助<br>2.這項資料集雖然來自UCI Machine Learning Repository但是資料的收集是來自Wisconsin Hospital歷年來所累積的病人資料<br>3.資料以結構化數值行資料為主<br>4.希望可以透過這項資料來達到乳癌的預測，以分類的方法例如：KNN、SVM、LG、RF等等，並且觀察他們的準確率

# %% [markdown]
# # 作業 2

# %% [markdown]
# 1.每台車輛的載客數是否增加來評斷業績的提升與否<br>2.在車輛上安裝Sensor或利用app並自行搜集資料<br>3.以數值型為主<br>4.以MSE來評估連續型資料
